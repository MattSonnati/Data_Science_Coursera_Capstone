# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# <h1 align=center><font size = 5>Exploratory Data Analysis: Paris Startup Ecosystem</font></h1>

# %% [markdown]
# ## Introduction
#
# In this notebook, we conduct an Exploratory Data Analysis (EDA) of data about Paris Startup Ecosystem collected from the Foutsquare API. The idea is to better understand what the startup ecosystem in Paris in order to compare it with others cities.
# Foursquare API being a geo dataset, the analysis will mainly revolve around geographical analysis and Data Visualization on maps. Our area of investigation will focus on the category and quantity of organizations and companies that are related to startup eosystem.
#
# Our EDA approach follows the **Data Science Methodology CRISP-DM**. For more info about this approach, check this [Wikipedia page](https://en.wikipedia.org/wiki/Cross-industry_standard_process_for_data_mining)

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item1">Data Collection</a>
#
# 2. <a href="#item2">Data Visualization</a>
#
# 3. <a href="#item3">Next steps</a>
#
# </font>
# </div>
# <a id='the_destination'></a>

# %% [markdown]
# First let's download all the libraries required for this notebook.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from bs4 import BeautifulSoup # library for web parsing 

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
import urllib.request
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

from lxml.html import fromstring

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Libraries imported.

# %% [markdown]
# ## 1. Data Collection <a id='item1'></a>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '1WWXCIS2F3IUWK01JHKKKJYCU1VDZDAOC52JOLFUE35NRK2M' #  Foursquare ID
CLIENT_SECRET = '4X1X0PXTZENNVWF3LPONZJ1GPMQQ0G1QNC1DGGMSHP53SPW3' #  Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1WWXCIS2F3IUWK01JHKKKJYCU1VDZDAOC52JOLFUE35NRK2M
# CLIENT_SECRET:4X1X0PXTZENNVWF3LPONZJ1GPMQQ0G1QNC1DGGMSHP53SPW3

# %% [markdown]
# #### Category selection

# %% [markdown]
# Foursquare has many categories. The full list can be accessed [here](https://developer.foursquare.com/docs/resources/categories). It goes from Restaurants to Stores and some of theses categories can widely impact any analysis just by their shear number of place. As a result, we decided to focus on selected categories that are more directely related to the life of startup, aka a Startup Ecosystem. We use the definition of a [Startup Ecosystem](https://en.wikipedia.org/wiki/Startup_ecosystem) according to Wikipedia.
# This list of category is definitely not exhaustive and could evolved based on the result of our analysis or any thoughtfull suggestions.

# %% [markdown]
# Obvisously the first category we selected was **Tech Startup** (4bf58dd8d48988d125941735) as this is the main focus of our analysis.
#
# Then we selected all the services that are required to the common operation of a startup:
# - **Coworking Space** (4bf58dd8d48988d174941735)
# - **Recruiting Agency** (52f2ab2ebcbc57f1066b8b57)
# - **Financial or Legal Service** (503287a291d4c4b30a586d65)
# - **Lawyer** (52f2ab2ebcbc57f1066b8b3f)
# - **Design Studio** (4bf58dd8d48988d1f4941735)
# - **Insurance Office** (58daa1558bbb0b01f18ec1f1)
# - **Business Service** (5453de49498eade8af355881)
# - **Business Center** (56aa371be4b08b9a8d573517)
# - **Advertising Agency** (52e81612bcbc57f1066b7a3d)
# - **Bank**	(4bf58dd8d48988d10a951735)
# - **Government Building**	(4bf58dd8d48988d126941735)
#
# We also selected the categories related to potential innovation partners of startup:
# - **College & University** (4d4b7105d754a06372d81259)
# - **Adult Education Center** (56aa371ce4b08b9a8d573570)
# - **Laboratory** (5744ccdfe4b0c0459246b4d6)
# - **Research Station** (58daa1558bbb0b01f18ec1b2)
#
# We also selected the categories related to potential industrial partners of startup:
# - **Industrial Estate** (56aa371be4b08b9a8d5734d7)
# - **Factory** (4eb1bea83b7b6f98df247e06)
#
# We also selected the categories related to potential cultural partners of startup:
# - **Library** (4bf58dd8d48988d12f941735)
# - **Science Museum** (4bf58dd8d48988d191941735)
# - **Art Museum** (4bf58dd8d48988d18f941735)
# - **History Museum** (4bf58dd8d48988d190941735)
# - **Planetarium** (4bf58dd8d48988d192941735)
#
#
#
# We then selected the category to various events that are required for startup to network and meet potential users or customers:
# - **Events** (4d4b7105d754a06373d81259)
# - **Trade Fair**	(5bae9231bedf3950379f89c3)
#
# The full list of categories was compiled in a csv file avaliable [here](https://raw.githubusercontent.com/MattSonnati/Data_Science_Coursera_Capstone/master/startup_ecosystem_category_list.csv)

# %%
startup_ecosystem_category_list = pd.read_csv('https://raw.githubusercontent.com/MattSonnati/Data_Science_Coursera_Capstone/master/startup_ecosystem_category_list.csv').dropna()
startup_ecosystem_category_list
# Out:
#              4sq_category_name                    4sq_id color_code
# 0                 Tech Startup  4bf58dd8d48988d125941735    #32CD32
# 1              Coworking Space  4bf58dd8d48988d174941735    #ADFF2F
# 2             Insurance Office  58daa1558bbb0b01f18ec1f1    #FFD700
# 3            Recruiting Agency  52f2ab2ebcbc57f1066b8b57    #FFFFE0
# 4   Financial or Legal Service  503287a291d4c4b30a586d65    #FFE4B5
# 5                       Lawyer  52f2ab2ebcbc57f1066b8b3f    #FFFF00
# 6                   Laboratory  5744ccdfe4b0c0459246b4d6    #87CEFA
# 7         College & University  4d4b7105d754a06372d81259    #00BFFF
# 8       Adult Education Center  56aa371ce4b08b9a8d573570    #6495ED
# 9             Research Station  58daa1558bbb0b01f18ec1b2    #4169E1
# 10                     Library  4bf58dd8d48988d12f941735    #000080
# 11              Science Museum  4bf58dd8d48988d191941735    #EE82EE
# 12                  Art Museum  4bf58dd8d48988d18f941735    #8A2BE2
# 13              History Museum  4bf58dd8d48988d190941735    #9932CC
# 14                 Planetarium  4bf58dd8d48988d192941735    #800080
# 15                      Events  4d4b7105d754a06373d81259    #FF69B4
# 16             Business Center  56aa371be4b08b9a8d573517    #FF6347
# 17          Advertising Agency  52e81612bcbc57f1066b7a3d    #DC143C
# 18            Business Service  5453de49498eade8af355881    #FFA500
# 19               Design Studio  4bf58dd8d48988d1f4941735    #FFA07A
# 20                     Factory  4eb1bea83b7b6f98df247e06    #808080
# 21           Industrial Estate  56aa371be4b08b9a8d5734d7    #C0C0C0
# 22                        Bank  4bf58dd8d48988d10a951735    #008000
# 23                  Trade Fair  5bae9231bedf3950379f89c3    #AFEEEE
# 24         Government Building  4bf58dd8d48988d126941735    #F8F8FF

# %% [markdown]
# #### Area selection

# %% [markdown]
# In many instance, the geographical area referred to by poiting at a specific city is much wider than the administrative boundaries of said city. For example when people talk about startup from the "Bay area", SF or the Silicon Valley, in fact they refer to several cities from San Fransisco, Palo alto, Mountain view up to San Jose.
#
# For Paris, we thus decided to include every cities within 50 km from Paris.

# %% [markdown]
# We thus ask Foursquare API to find all the City (50aa9e094b90af0d42d5de0d) within 50000 meters from Paris, France

# %%
address_near = "Paris, France"
radius = 50000
category_id = "50aa9e094b90af0d42d5de0d"

# %%
# function that extracts the category name of the venue
def get_category_name(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
    # function that extracts the category of the venue
def get_category_id(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['id']
    
#create the GET request URL
LIMIT = 200

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&near={}&v={}&radius={}&limit={}&intent=browse&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    address_near,  
    VERSION, 
    radius, 
    LIMIT,
    category_id)

# Send the GET request 
results = requests.get(url).json()

# Convert the JSON response into a dataframe
cities = results['response']['venues']
cities_list = json_normalize(cities) # flatten JSON

# filter columns
filtered_columns = ['name',
                    'id',
                    'location.postalCode',
                    'location.state',
                    'location.country',
                    'location.cc',
                    'location.lat', 
                    'location.lng',
                    'categories',]
cities_list =cities_list.loc[:, filtered_columns]

# filter the category for each row
cities_list['primary_category_name'] = cities_list.apply(get_category_name, axis=1)
cities_list['primary_category_id'] = cities_list.apply(get_category_id, axis=1)

# clean columns
cities_list.columns = [col.split(".")[-1] for col in cities_list.columns]

cities_list.head()
# Out:
#                    name                        id postalCode          state  \
# 0                 Paris  50dbd18d498eb594ef575b0a      75000  Île-de-France
# 1      Levallois-Perret  4ccc49e754f0b1f79d4515ca      92300  Île-de-France
# 2            Versailles  4b92dff4f964a5207e2334e3      78000  Île-de-France
# 3     Neuilly-sur-Seine  509f8996e4b05e06b5811a17      92200  Île-de-France
# 4  Boulogne-Billancourt  4c80bf1e74d7b60c080670d8      92100  Île-de-France
#
#   country  cc        lat       lng  \
# 0  France  FR  48.857006  2.351490
# 1  France  FR  48.893985  2.288295
# 2  France  FR  48.803472  2.126884
# 3  France  FR  48.884924  2.269471
# 4  France  FR  48.834141  2.242686
#
#                                           categories primary_category_name  \
# 0  [{'primary': True, 'name': 'City', 'icon': {'s...                  City
# 1  [{'primary': True, 'name': 'City', 'icon': {'s...                  City
# 2  [{'primary': True, 'name': 'City', 'icon': {'s...                  City
# 3  [{'primary': True, 'name': 'City', 'icon': {'s...                  City
# 4  [{'primary': True, 'name': 'City', 'icon': {'s...                  City
#
#         primary_category_id
# 0  50aa9e094b90af0d42d5de0d
# 1  50aa9e094b90af0d42d5de0d
# 2  50aa9e094b90af0d42d5de0d
# 3  50aa9e094b90af0d42d5de0d
# 4  50aa9e094b90af0d42d5de0d

# %%
cities_list.shape
# Out:
# (50, 11)

# %%
# Save dataframe as csv file to storage
project.save_data(data=cities_list.to_csv(index=False),file_name='paris_cities_list.csv',overwrite=True)
# Out:
# {'asset_id': 'cfbb8c76-a49c-401c-a7cb-893c296837a2',
#  'bucket_name': 'ibmdatasciencecapstoneproject-donotdelete-pr-mbjulyaztk4qgf',
#  'file_name': 'paris_cities_list.csv',
#  'message': 'File saved to project storage.'}

# %% [markdown]
# #### List of Startup Ecosystem places in Paris area

# %% [markdown]
# For each city in the chosen area, we list all the places in our Category selection and within 5 km of said city.

# %%
def getCategoryVenues(name, latitude, longitude, radius, category_id):
    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&intent=browse&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    latitude, 
    longitude, 
    VERSION,
    radius, 
    LIMIT,
    category_id)

    # Send the GET request 
    results = requests.get(url).json()

    # Convert the JSON response into a dataframe
    category_venues = results['response']['venues']
    category_venues_list = json_normalize(category_venues) # flatten JSON

    # filter columns
    filtered_columns = ['name',
                            'id',
                            'location.postalCode',
                            'location.state',
                            'location.country',
                            'location.cc',
                            'location.lat', 
                            'location.lng',
                            'categories',]
    category_venues_list = category_venues_list.loc[:, filtered_columns]

    # filter the category for each row
    category_venues_list['primary_category_name'] = category_venues_list.apply(get_category_name, axis=1)
    category_venues_list['primary_category_id'] = category_venues_list.apply(get_category_id, axis=1)

    # clean columns
    category_venues_list.columns = [col.split(".")[-1] for col in category_venues_list.columns]

    return(category_venues_list)

# %%
radius = 5000
startup_ecosystem_place_list = pd.DataFrame(columns=['name','id','city','postalCode','state','country','cc','lat','lng','categoriesList','primary_category_name','primary_category_id'])

for category_name, category_id, color_code  in zip(startup_ecosystem_category_list['4sq_category_name'],
                                          startup_ecosystem_category_list['4sq_id'],
                                          startup_ecosystem_category_list['color_code']):
   
    for latitude, longitude, name  in zip(cities_list['lat'],
                                          cities_list['lng'],
                                          cities_list['name']):
        try:
            startup_ecosystem_place_list = pd.concat([startup_ecosystem_place_list, getCategoryVenues(name, latitude, longitude, radius, category_id)])
        except:
            pass

startup_ecosystem_place_list.drop_duplicates(subset=['id'], keep='first', inplace=True)
startup_ecosystem_place_list.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:31: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                           categories categoriesList  cc city  \
# 0  [{'primary': True, 'name': 'Tech Startup', 'ic...            NaN  FR  NaN
# 1  [{'primary': True, 'name': 'Tech Startup', 'ic...            NaN  FR  NaN
# 2  [{'primary': True, 'name': 'Tech Startup', 'ic...            NaN  FR  NaN
# 3  [{'primary': True, 'name': 'Tech Startup', 'ic...            NaN  FR  NaN
# 4  [{'primary': True, 'name': 'Tech Startup', 'ic...            NaN  FR  NaN
#
#   country                        id        lat       lng matt_category_color  \
# 0  France  58a16c5f51d19e06ce98f38d  48.868517  2.345687                 NaN
# 1  France  4dac5df543a112819724533f  48.856391  2.293381                 NaN
# 2  France  59f711f53d4791157b9e7f62  48.880447  2.327044                 NaN
# 3  France  4fdee1f3e4b014c45c45905c  48.879049  2.332151                 NaN
# 4  France  59e9b4ec3abcaf334aa66d07  48.872823  2.350290                 NaN
#
#   matt_category_id matt_category_name               name postalCode  \
# 0              NaN                NaN           Qonto HQ      75003
# 1              NaN                NaN  Salesforce France      75007
# 2              NaN                NaN            Algolia      75008
# 3              NaN                NaN             Criteo      75009
# 4              NaN                NaN        Spendesk HQ      75010
#
#         primary_category_id primary_category_name          state
# 0  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 1  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 2  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 3  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 4  4bf58dd8d48988d125941735          Tech Startup  Île-de-France

# %%
startup_ecosystem_place_list.shape
# Out:
# (5656, 16)

# %%
# Save dataframe as csv file to storage
project.save_data(data=startup_ecosystem_place_list.to_csv(index=False),file_name='paris_startup_ecosystem_place_list.csv',overwrite=True)
# Out:
# {'asset_id': '6781b59d-f4dc-4b88-9680-065a9f2e93d2',
#  'bucket_name': 'ibmdatasciencecapstoneproject-donotdelete-pr-mbjulyaztk4qgf',
#  'file_name': 'paris_startup_ecosystem_place_list.csv',
#  'message': 'File saved to project storage.'}

# %% [markdown]
# ## 2. Data Visualization <a id='item2'></a>

# %% [markdown]
# First, let define a function to creat map from a list of Place based on their latitude and longitude coordinate.

# %%
def getMap(centerPlace, venues_list):

    # create a user agent
    geolocator = Nominatim(user_agent="fr_explorer")

    address = centerPlace
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude

    # create map using latitude and longitude values
    map_venues = folium.Map(location=[latitude, longitude], zoom_start=11)

    # add markers to map
    for lat, lng, name, postalCode  in zip(venues_list['lat'], 
                                                          venues_list['lng'], 
                                                          venues_list['name'], 
                                                          venues_list['postalCode']):
        label = '{} {}'.format(name, postalCode)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_venues)  

    return(map_venues)

# %% [markdown]
# Map of cities within 50 km from Paris

# %%
 getMap('Paris, france', cities_list)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### To better understand Paris Startup Ecosystem, we can take a look at the number of place in each categories.

# %% [markdown]
# In order to better visualize these data, we can plot them as a horizontal bar plot.

# %%
count_per_category = startup_ecosystem_place_list.groupby('primary_category_name').count()
count_per_category.drop(['categories','categoriesList','state','postalCode','city'], axis=1, inplace=True)
count_per_category.sort_values(['id'], ascending=True, axis=0, inplace=True)
count_per_category
# Out:
#                                   cc  country   id  lat  lng  \
# primary_category_name
# Accessories Store                  1        1    1    1    1
# Memorial Site                      1        1    1    1    1
# Lighting Store                     1        1    1    1    1
# Jewelry Store                      1        1    1    1    1
# Hotel                              1        1    1    1    1
# Health & Beauty Service            1        1    1    1    1
# Gym                                1        1    1    1    1
# Garden                             1        1    1    1    1
# French Restaurant                  1        1    1    1    1
# Waste Facility                     1        1    1    1    1
# Fountain                           1        1    1    1    1
# Festival                           1        1    1    1    1
# Fair                               1        1    1    1    1
# Fabric Shop                        1        1    1    1    1
# Exhibit                            1        1    1    1    1
# Doner Restaurant                   1        1    1    1    1
# Doctor's Office                    1        1    1    1    1
# Dance Studio                       1        1    1    1    1
# Currency Exchange                  1        1    1    1    1
# Cosmetics Shop                     1        1    1    1    1
# Military Base                      1        1    1    1    1
# Convention Center                  1        1    1    1    1
# Mobile Phone Shop                  1        1    1    1    1
# Newsstand                          1        1    1    1    1
# Veterinarian                       1        1    1    1    1
# Trade Fair                         1        1    1    1    1
# Town Hall                          1        1    1    1    1
# Tourist Information Center         1        1    1    1    1
# Thrift / Vintage Store             1        1    1    1    1
# Tennis Stadium                     1        1    1    1    1
# TV Station                         1        1    1    1    1
# Street Fair                        1        1    1    1    1
# Shoe Store                         1        1    1    1    1
# Sculpture Garden                   1        1    1    1    1
# Rental Service                     1        1    1    1    1
# Radio Station                      1        1    1    1    1
# Professional & Other Places        1        1    1    1    1
# Photography Lab                    1        1    1    1    1
# Pet Service                        1        1    1    1    1
# Performing Arts Venue              1        1    1    1    1
# Pedestrian Plaza                   1        1    1    1    1
# Paper / Office Supplies Store      1        1    1    1    1
# Outdoor Sculpture                  1        1    1    1    1
# Music School                       1        1    1    1    1
# Comedy Club                        1        1    1    1    1
# Wine Bar                           1        1    1    1    1
# Alternative Healer                 1        1    1    1    1
# Arts & Crafts Store                1        1    1    1    1
# Auto Dealership                    1        1    1    1    1
# Auto Workshop                      1        1    1    1    1
# Christmas Market                   1        1    1    1    1
# Big Box Store                      1        1    1    1    1
# Bike Shop                          1        1    1    1    1
# Chocolate Shop                     1        1    1    1    1
# Child Care Service                 1        1    1    1    1
# Clothing Store                     1        1    1    1    1
# Castle                             1        1    1    1    1
# Camera Store                       1        1    1    1    1
# College Technology Building        2        2    2    2    2
# Hospital                           2        2    2    2    2
# Men's Store                        2        2    2    2    2
# Museum                             2        2    2    2    2
# Bridge                             2        2    2    2    2
# Café                               2        2    2    2    2
# Boutique                           2        2    2    2    2
# Planetarium                        2        2    2    2    2
# Bookstore                          2        2    2    2    2
# Automotive Shop                    2        2    2    2    2
# Transportation Service             2        2    2    2    2
# Other Repair Shop                  2        2    2    2    2
# Gift Shop                          2        2    2    2    2
# Fraternity House                   2        2    2    2    2
# College Theater                    2        2    2    2    2
# Event Service                      2        2    2    2    2
# Concert Hall                       2        2    2    2    2
# Non-Profit                         3        3    3    3    3
# College Communications Building    3        3    3    3    3
# Other Event                        3        3    3    3    3
# Medical Center                     3        3    3    3    3
# Event Space                        3        3    3    3    3
# College Stadium                    3        3    3    3    3
# Cultural Center                    3        3    3    3    3
# Supermarket                        3        3    3    3    3
# Conference                         3        3    3    3    3
# College Bookstore                  4        4    4    4    4
# Capitol Building                   4        4    4    4    4
# Art Gallery                        4        4    4    4    4
# General Entertainment              4        4    4    4    4
# Historic Site                      5        5    5    5    5
# Convention                         5        5    5    5    5
# Electronics Store                  5        5    5    5    5
# Industrial Estate                  5        5    5    5    5
# College & University               5        5    5    5    5
# Community College                  5        5    5    5    5
# Law School                         5        5    5    5    5
# Church                             6        6    6    6    6
# Medical School                     6        6    6    6    6
# Print Shop                         6        6    6    6    6
# Coffee Shop                        6        6    6    6    6
# College Lab                        7        7    7    7    7
# Photography Studio                 7        7    7    7    7
# Fire Station                       7        7    7    7    7
# Research Station                   7        7    7    7    7
# College Science Building           7        7    7    7    7
# School                             8        8    8    8    8
# Building                           9        9    9    9    9
# Courthouse                         9        9    9    9    9
# IT Services                       10       10   10   10   10
# College Administrative Building   11       11   11   11   11
# College Arts Building             11       11   11   11   11
# College Engineering Building      11       11   11   11   11
# College Auditorium                12       12   12   12   12
# Furniture / Home Store            12       12   12   12   12
# Gas Station                       12       12   12   12   12
# Real Estate Office                13       13   13   13   13
# College Gym                       14       14   14   14   14
# Construction & Landscaping        15       15   15   15   15
# College Cafeteria                 16       16   16   16   16
# Post Office                       17       17   17   17   17
# College Residence Hall            19       19   19   19   19
# Embassy / Consulate               21       21   21   21   21
# Student Center                    21       21   21   21   21
# Miscellaneous Shop                22       22   22   22   22
# Monument / Landmark               24       24   24   24   24
# Home Service                      24       24   24   24   24
# Trade School                      24       24   24   24   24
# College Classroom                 25       25   25   25   25
# Police Station                    28       28   28   28   28
# Science Museum                    29       29   29   29   29
# College Academic Building         30       30   30   30   30
# College Library                   35       35   35   35   35
# Laboratory                        37       37   37   37   37
# General College & University      44       44   44   44   44
# University                        45       45   45   45   45
# Adult Education Center            50       50   50   50   50
# History Museum                    58       58   58   58   58
# Office                            72       72   72   72   72
# City Hall                         78       78   78   78   78
# Art Museum                       105      105  105  105  105
# Government Building              109      109  109  109  109
# Business Center                  167      167  167  167  167
# Recruiting Agency                180      180  180  180  180
# Lawyer                           237      237  237  237  237
# Financial or Legal Service       272      272  272  272  272
# Library                          274      274  274  274  274
# Insurance Office                 298      298  298  298  298
# Factory                          309      309  309  309  309
# Advertising Agency               316      316  316  316  316
# Business Service                 325      325  325  325  325
# Design Studio                    338      338  338  338  338
# Coworking Space                  471      471  471  471  471
# Tech Startup                     520      520  520  520  520
# Bank                             639      639  639  639  639
#
#                                  matt_category_color  matt_category_id  \
# primary_category_name
# Accessories Store                                  0                 0
# Memorial Site                                      0                 0
# Lighting Store                                     0                 0
# Jewelry Store                                      0                 0
# Hotel                                              0                 0
# Health & Beauty Service                            0                 0
# Gym                                                0                 0
# Garden                                             0                 0
# French Restaurant                                  0                 0
# Waste Facility                                     0                 0
# Fountain                                           0                 0
# Festival                                           0                 0
# Fair                                               0                 0
# Fabric Shop                                        0                 0
# Exhibit                                            0                 0
# Doner Restaurant                                   0                 0
# Doctor's Office                                    0                 0
# Dance Studio                                       0                 0
# Currency Exchange                                  0                 0
# Cosmetics Shop                                     0                 0
# Military Base                                      0                 0
# Convention Center                                  0                 0
# Mobile Phone Shop                                  0                 0
# Newsstand                                          0                 0
# Veterinarian                                       0                 0
# Trade Fair                                         0                 0
# Town Hall                                          0                 0
# Tourist Information Center                         0                 0
# Thrift / Vintage Store                             0                 0
# Tennis Stadium                                     0                 0
# TV Station                                         0                 0
# Street Fair                                        0                 0
# Shoe Store                                         0                 0
# Sculpture Garden                                   0                 0
# Rental Service                                     0                 0
# Radio Station                                      0                 0
# Professional & Other Places                        0                 0
# Photography Lab                                    0                 0
# Pet Service                                        0                 0
# Performing Arts Venue                              0                 0
# Pedestrian Plaza                                   0                 0
# Paper / Office Supplies Store                      0                 0
# Outdoor Sculpture                                  0                 0
# Music School                                       0                 0
# Comedy Club                                        0                 0
# Wine Bar                                           0                 0
# Alternative Healer                                 0                 0
# Arts & Crafts Store                                0                 0
# Auto Dealership                                    0                 0
# Auto Workshop                                      0                 0
# Christmas Market                                   0                 0
# Big Box Store                                      0                 0
# Bike Shop                                          0                 0
# Chocolate Shop                                     0                 0
# Child Care Service                                 0                 0
# Clothing Store                                     0                 0
# Castle                                             0                 0
# Camera Store                                       0                 0
# College Technology Building                        0                 0
# Hospital                                           0                 0
# Men's Store                                        0                 0
# Museum                                             0                 0
# Bridge                                             0                 0
# Café                                               0                 0
# Boutique                                           0                 0
# Planetarium                                        0                 0
# Bookstore                                          0                 0
# Automotive Shop                                    0                 0
# Transportation Service                             0                 0
# Other Repair Shop                                  0                 0
# Gift Shop                                          0                 0
# Fraternity House                                   0                 0
# College Theater                                    0                 0
# Event Service                                      0                 0
# Concert Hall                                       0                 0
# Non-Profit                                         0                 0
# College Communications Building                    0                 0
# Other Event                                        0                 0
# Medical Center                                     0                 0
# Event Space                                        0                 0
# College Stadium                                    0                 0
# Cultural Center                                    0                 0
# Supermarket                                        0                 0
# Conference                                         0                 0
# College Bookstore                                  0                 0
# Capitol Building                                   0                 0
# Art Gallery                                        0                 0
# General Entertainment                              0                 0
# Historic Site                                      0                 0
# Convention                                         0                 0
# Electronics Store                                  0                 0
# Industrial Estate                                  0                 0
# College & University                               0                 0
# Community College                                  0                 0
# Law School                                         0                 0
# Church                                             0                 0
# Medical School                                     0                 0
# Print Shop                                         0                 0
# Coffee Shop                                        0                 0
# College Lab                                        0                 0
# Photography Studio                                 0                 0
# Fire Station                                       0                 0
# Research Station                                   0                 0
# College Science Building                           0                 0
# School                                             0                 0
# Building                                           0                 0
# Courthouse                                         0                 0
# IT Services                                        0                 0
# College Administrative Building                    0                 0
# College Arts Building                              0                 0
# College Engineering Building                       0                 0
# College Auditorium                                 0                 0
# Furniture / Home Store                             0                 0
# Gas Station                                        0                 0
# Real Estate Office                                 0                 0
# College Gym                                        0                 0
# Construction & Landscaping                         0                 0
# College Cafeteria                                  0                 0
# Post Office                                        0                 0
# College Residence Hall                             0                 0
# Embassy / Consulate                                0                 0
# Student Center                                     0                 0
# Miscellaneous Shop                                 0                 0
# Monument / Landmark                                0                 0
# Home Service                                       0                 0
# Trade School                                       0                 0
# College Classroom                                  0                 0
# Police Station                                     0                 0
# Science Museum                                     0                 0
# College Academic Building                          0                 0
# College Library                                    0                 0
# Laboratory                                         0                 0
# General College & University                       0                 0
# University                                         0                 0
# Adult Education Center                             0                 0
# History Museum                                     0                 0
# Office                                             0                 0
# City Hall                                          0                 0
# Art Museum                                         0                 0
# Government Building                                0                 0
# Business Center                                    0                 0
# Recruiting Agency                                  0                 0
# Lawyer                                             0                 0
# Financial or Legal Service                         0                 0
# Library                                            0                 0
# Insurance Office                                   0                 0
# Factory                                            0                 0
# Advertising Agency                                 0                 0
# Business Service                                   0                 0
# Design Studio                                      0                 0
# Coworking Space                                    0                 0
# Tech Startup                                       0                 0
# Bank                                               0                 0
#
#                                  matt_category_name  name  primary_category_id
# primary_category_name
# Accessories Store                                 0     1                    1
# Memorial Site                                     0     1                    1
# Lighting Store                                    0     1                    1
# Jewelry Store                                     0     1                    1
# Hotel                                             0     1                    1
# Health & Beauty Service                           0     1                    1
# Gym                                               0     1                    1
# Garden                                            0     1                    1
# French Restaurant                                 0     1                    1
# Waste Facility                                    0     1                    1
# Fountain                                          0     1                    1
# Festival                                          0     1                    1
# Fair                                              0     1                    1
# Fabric Shop                                       0     1                    1
# Exhibit                                           0     1                    1
# Doner Restaurant                                  0     1                    1
# Doctor's Office                                   0     1                    1
# Dance Studio                                      0     1                    1
# Currency Exchange                                 0     1                    1
# Cosmetics Shop                                    0     1                    1
# Military Base                                     0     1                    1
# Convention Center                                 0     1                    1
# Mobile Phone Shop                                 0     1                    1
# Newsstand                                         0     1                    1
# Veterinarian                                      0     1                    1
# Trade Fair                                        0     1                    1
# Town Hall                                         0     1                    1
# Tourist Information Center                        0     1                    1
# Thrift / Vintage Store                            0     1                    1
# Tennis Stadium                                    0     1                    1
# TV Station                                        0     1                    1
# Street Fair                                       0     1                    1
# Shoe Store                                        0     1                    1
# Sculpture Garden                                  0     1                    1
# Rental Service                                    0     1                    1
# Radio Station                                     0     1                    1
# Professional & Other Places                       0     1                    1
# Photography Lab                                   0     1                    1
# Pet Service                                       0     1                    1
# Performing Arts Venue                             0     1                    1
# Pedestrian Plaza                                  0     1                    1
# Paper / Office Supplies Store                     0     1                    1
# Outdoor Sculpture                                 0     1                    1
# Music School                                      0     1                    1
# Comedy Club                                       0     1                    1
# Wine Bar                                          0     1                    1
# Alternative Healer                                0     1                    1
# Arts & Crafts Store                               0     1                    1
# Auto Dealership                                   0     1                    1
# Auto Workshop                                     0     1                    1
# Christmas Market                                  0     1                    1
# Big Box Store                                     0     1                    1
# Bike Shop                                         0     1                    1
# Chocolate Shop                                    0     1                    1
# Child Care Service                                0     1                    1
# Clothing Store                                    0     1                    1
# Castle                                            0     1                    1
# Camera Store                                      0     1                    1
# College Technology Building                       0     2                    2
# Hospital                                          0     2                    2
# Men's Store                                       0     2                    2
# Museum                                            0     2                    2
# Bridge                                            0     2                    2
# Café                                              0     2                    2
# Boutique                                          0     2                    2
# Planetarium                                       0     2                    2
# Bookstore                                         0     2                    2
# Automotive Shop                                   0     2                    2
# Transportation Service                            0     2                    2
# Other Repair Shop                                 0     2                    2
# Gift Shop                                         0     2                    2
# Fraternity House                                  0     2                    2
# College Theater                                   0     2                    2
# Event Service                                     0     2                    2
# Concert Hall                                      0     2                    2
# Non-Profit                                        0     3                    3
# College Communications Building                   0     3                    3
# Other Event                                       0     3                    3
# Medical Center                                    0     3                    3
# Event Space                                       0     3                    3
# College Stadium                                   0     3                    3
# Cultural Center                                   0     3                    3
# Supermarket                                       0     3                    3
# Conference                                        0     3                    3
# College Bookstore                                 0     4                    4
# Capitol Building                                  0     4                    4
# Art Gallery                                       0     4                    4
# General Entertainment                             0     4                    4
# Historic Site                                     0     5                    5
# Convention                                        0     5                    5
# Electronics Store                                 0     5                    5
# Industrial Estate                                 0     5                    5
# College & University                              0     5                    5
# Community College                                 0     5                    5
# Law School                                        0     5                    5
# Church                                            0     6                    6
# Medical School                                    0     6                    6
# Print Shop                                        0     6                    6
# Coffee Shop                                       0     6                    6
# College Lab                                       0     7                    7
# Photography Studio                                0     7                    7
# Fire Station                                      0     7                    7
# Research Station                                  0     7                    7
# College Science Building                          0     7                    7
# School                                            0     8                    8
# Building                                          0     9                    9
# Courthouse                                        0     9                    9
# IT Services                                       0    10                   10
# College Administrative Building                   0    11                   11
# College Arts Building                             0    11                   11
# College Engineering Building                      0    11                   11
# College Auditorium                                0    12                   12
# Furniture / Home Store                            0    12                   12
# Gas Station                                       0    12                   12
# Real Estate Office                                0    13                   13
# College Gym                                       0    14                   14
# Construction & Landscaping                        0    15                   15
# College Cafeteria                                 0    16                   16
# Post Office                                       0    17                   17
# College Residence Hall                            0    19                   19
# Embassy / Consulate                               0    21                   21
# Student Center                                    0    21                   21
# Miscellaneous Shop                                0    22                   22
# Monument / Landmark                               0    24                   24
# Home Service                                      0    24                   24
# Trade School                                      0    24                   24
# College Classroom                                 0    25                   25
# Police Station                                    0    28                   28
# Science Museum                                    0    29                   29
# College Academic Building                         0    30                   30
# College Library                                   0    35                   35
# Laboratory                                        0    37                   37
# General College & University                      0    44                   44
# University                                        0    45                   45
# Adult Education Center                            0    50                   50
# History Museum                                    0    58                   58
# Office                                            0    72                   72
# City Hall                                         0    78                   78
# Art Museum                                        0   105                  105
# Government Building                               0   109                  109
# Business Center                                   0   167                  167
# Recruiting Agency                                 0   180                  180
# Lawyer                                            0   237                  237
# Financial or Legal Service                        0   272                  272
# Library                                           0   274                  274
# Insurance Office                                  0   298                  298
# Factory                                           0   309                  309
# Advertising Agency                                0   316                  316
# Business Service                                  0   325                  325
# Design Studio                                     0   338                  338
# Coworking Space                                   0   471                  471
# Tech Startup                                      0   520                  520
# Bank                                              0   639                  639

# %%
# plot data
count_per_category['id'].tail(50).plot(kind='barh', figsize=(10, 20))

plt.xlabel('Number of Recommended places of this category in Paris') # add to x-label to the plot
plt.ylabel('Place Category') # add y-label to the plot
plt.title('Category of Recommended places in Paris') # add title to the plot
plt.legend('') # add title to the plot

plt.show()

# %% [markdown]
# ## 3. Next Steps <a id='item3'></a>

# %% [markdown]
# In this notebook, we have collected data about Paris Startup Ecosystem. We then had a quick glance about the data through a map and an histogram. These data will be combined with others similar data from other Startup Ecosystem in the world then analyzed in a subsequent notebook. Then we will try to compare and identify similarity among these Startup Ecosystem through machine learning clustering techniques.
